# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 0.0066 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00226, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 0.0017 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00226 to 0.00196, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 0.0013 - val_loss: 0.0020
#
# Epoch 00003: val_loss did not improve from 0.00196
# Epoch 4/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 0.0012 - val_loss: 0.0020
#
# Epoch 00004: val_loss did not improve from 0.00196
# Epoch 5/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 0.0011 - val_loss: 0.0020
#
# Epoch 00005: val_loss improved from 0.00196 to 0.00196, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00196 to 0.00185, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 9.0002e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00185 to 0.00167, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 7.7754e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00167 to 0.00150, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 6.7042e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00150 to 0.00138, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 6.1573e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00138 to 0.00131, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 5.8157e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00131 to 0.00123, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 5.0970e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00123 to 0.00114, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 4.9147e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00114 to 0.00107, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 4.4971e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00107
# Epoch 15/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 4.2265e-04 - val_loss: 0.0010
#
# Epoch 00015: val_loss improved from 0.00107 to 0.00102, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 3.9569e-04 - val_loss: 9.6668e-04
#
# Epoch 00016: val_loss improved from 0.00102 to 0.00097, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 3.7326e-04 - val_loss: 9.4436e-04
#
# Epoch 00017: val_loss improved from 0.00097 to 0.00094, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 3.6944e-04 - val_loss: 9.2251e-04
#
# Epoch 00018: val_loss improved from 0.00094 to 0.00092, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 3.5453e-04 - val_loss: 8.9365e-04
#
# Epoch 00019: val_loss improved from 0.00092 to 0.00089, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 3.3451e-04 - val_loss: 8.9005e-04
#
# Epoch 00020: val_loss improved from 0.00089 to 0.00089, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 3.2229e-04 - val_loss: 8.8873e-04
#
# Epoch 00021: val_loss improved from 0.00089 to 0.00089, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 3.1608e-04 - val_loss: 8.9514e-04
#
# Epoch 00022: val_loss did not improve from 0.00089
# Epoch 23/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 3.0390e-04 - val_loss: 8.3765e-04
#
# Epoch 00023: val_loss improved from 0.00089 to 0.00084, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 2.9351e-04 - val_loss: 8.3162e-04
#
# Epoch 00024: val_loss improved from 0.00084 to 0.00083, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 2.8888e-04 - val_loss: 8.4083e-04
#
# Epoch 00025: val_loss did not improve from 0.00083
# Epoch 26/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 2.8494e-04 - val_loss: 8.4772e-04
#
# Epoch 00026: val_loss did not improve from 0.00083
# Epoch 27/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 2.7175e-04 - val_loss: 8.1568e-04
#
# Epoch 00027: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 2.6016e-04 - val_loss: 8.3081e-04
#
# Epoch 00028: val_loss did not improve from 0.00082
# Epoch 29/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 2.5136e-04 - val_loss: 7.9585e-04
#
# Epoch 00029: val_loss improved from 0.00082 to 0.00080, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 2.5120e-04 - val_loss: 7.9596e-04
#
# Epoch 00030: val_loss did not improve from 0.00080
# Epoch 31/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 2.4472e-04 - val_loss: 8.0020e-04
#
# Epoch 00031: val_loss did not improve from 0.00080
# Epoch 32/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 2.4993e-04 - val_loss: 8.3765e-04
#
# Epoch 00032: val_loss did not improve from 0.00080
# Epoch 33/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 2.4063e-04 - val_loss: 9.0076e-04
#
# Epoch 00033: val_loss did not improve from 0.00080
# Epoch 34/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 2.3581e-04 - val_loss: 7.8657e-04
#
# Epoch 00034: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 2.2574e-04 - val_loss: 7.6869e-04
#
# Epoch 00035: val_loss improved from 0.00079 to 0.00077, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 2.3439e-04 - val_loss: 8.2594e-04
#
# Epoch 00036: val_loss did not improve from 0.00077
# Epoch 37/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 2.2130e-04 - val_loss: 7.9545e-04
#
# Epoch 00037: val_loss did not improve from 0.00077
# Epoch 38/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 2.1585e-04 - val_loss: 7.9138e-04
#
# Epoch 00038: val_loss did not improve from 0.00077
# Epoch 39/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 2.0959e-04 - val_loss: 7.8835e-04
#
# Epoch 00039: val_loss did not improve from 0.00077
# Epoch 40/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 2.0512e-04 - val_loss: 8.0767e-04
#
# Epoch 00040: val_loss did not improve from 0.00077
# Epoch 41/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 2.0144e-04 - val_loss: 7.9136e-04
#
# Epoch 00041: val_loss did not improve from 0.00077
# Epoch 42/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 2.0011e-04 - val_loss: 7.9092e-04
#
# Epoch 00042: val_loss did not improve from 0.00077
# Epoch 43/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.9759e-04 - val_loss: 7.5198e-04
#
# Epoch 00043: val_loss improved from 0.00077 to 0.00075, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.9851e-04 - val_loss: 7.7102e-04
#
# Epoch 00044: val_loss did not improve from 0.00075
# Epoch 45/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.9314e-04 - val_loss: 7.7495e-04
#
# Epoch 00045: val_loss did not improve from 0.00075
# Epoch 46/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 1.9028e-04 - val_loss: 7.7431e-04
#
# Epoch 00046: val_loss did not improve from 0.00075
# Epoch 47/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.8544e-04 - val_loss: 7.9329e-04
#
# Epoch 00047: val_loss did not improve from 0.00075
# Epoch 48/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.8430e-04 - val_loss: 7.5789e-04
#
# Epoch 00048: val_loss did not improve from 0.00075
# Epoch 49/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.8221e-04 - val_loss: 7.7007e-04
#
# Epoch 00049: val_loss did not improve from 0.00075
# Epoch 50/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 1.7518e-04 - val_loss: 8.2276e-04
#
# Epoch 00050: val_loss did not improve from 0.00075
# Epoch 51/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.7585e-04 - val_loss: 7.8520e-04
#
# Epoch 00051: val_loss did not improve from 0.00075
# Epoch 52/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.7216e-04 - val_loss: 8.0491e-04
#
# Epoch 00052: val_loss did not improve from 0.00075
# Epoch 53/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.7904e-04 - val_loss: 8.1619e-04
#
# Epoch 00053: val_loss did not improve from 0.00075
# Epoch 54/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.6807e-04 - val_loss: 7.7188e-04
#
# Epoch 00054: val_loss did not improve from 0.00075
# Epoch 55/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.6512e-04 - val_loss: 7.8342e-04
#
# Epoch 00055: val_loss did not improve from 0.00075
# Epoch 56/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.7342e-04 - val_loss: 7.9849e-04
#
# Epoch 00056: val_loss did not improve from 0.00075
# Epoch 57/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.6926e-04 - val_loss: 8.1600e-04
#
# Epoch 00057: val_loss did not improve from 0.00075
# Epoch 58/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.5954e-04 - val_loss: 7.9476e-04
#
# Epoch 00058: val_loss did not improve from 0.00075
# Epoch 59/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.5744e-04 - val_loss: 7.6607e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.5225e-04 - val_loss: 7.3031e-04
#
# Epoch 00060: val_loss improved from 0.00075 to 0.00073, saving model to best_weights.h5
# Epoch 61/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.5913e-04 - val_loss: 7.6885e-04
#
# Epoch 00061: val_loss did not improve from 0.00073
# Epoch 62/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.5681e-04 - val_loss: 8.1015e-04
#
# Epoch 00062: val_loss did not improve from 0.00073
# Epoch 63/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.5492e-04 - val_loss: 7.7511e-04
#
# Epoch 00063: val_loss did not improve from 0.00073
# Epoch 64/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.5344e-04 - val_loss: 7.5311e-04
#
# Epoch 00064: val_loss did not improve from 0.00073
# Epoch 65/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.4892e-04 - val_loss: 7.9678e-04
#
# Epoch 00065: val_loss did not improve from 0.00073
# Epoch 66/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.4914e-04 - val_loss: 7.4888e-04
#
# Epoch 00066: val_loss did not improve from 0.00073
# Epoch 67/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.4621e-04 - val_loss: 7.5362e-04
#
# Epoch 00067: val_loss did not improve from 0.00073
# Epoch 68/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.5045e-04 - val_loss: 7.3716e-04
#
# Epoch 00068: val_loss did not improve from 0.00073
# Epoch 69/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.4278e-04 - val_loss: 7.3829e-04
#
# Epoch 00069: val_loss did not improve from 0.00073
# Epoch 70/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.4324e-04 - val_loss: 8.0679e-04
#
# Epoch 00070: val_loss did not improve from 0.00073
# Epoch 71/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.4182e-04 - val_loss: 7.4942e-04
#
# Epoch 00071: val_loss did not improve from 0.00073
# Epoch 72/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.4305e-04 - val_loss: 7.6172e-04
#
# Epoch 00072: val_loss did not improve from 0.00073
# Epoch 73/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.4405e-04 - val_loss: 7.5217e-04
#
# Epoch 00073: val_loss did not improve from 0.00073
# Epoch 74/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.3753e-04 - val_loss: 7.8017e-04
#
# Epoch 00074: val_loss did not improve from 0.00073
# Epoch 75/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.3931e-04 - val_loss: 7.7817e-04
#
# Epoch 00075: val_loss did not improve from 0.00073
# Epoch 76/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 1.3590e-04 - val_loss: 7.3162e-04
#
# Epoch 00076: val_loss did not improve from 0.00073
# Epoch 77/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.3777e-04 - val_loss: 7.3027e-04
#
# Epoch 00077: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 78/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 1.3834e-04 - val_loss: 7.3763e-04
#
# Epoch 00078: val_loss did not improve from 0.00073
# Epoch 79/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 1.3529e-04 - val_loss: 7.5835e-04
#
# Epoch 00079: val_loss did not improve from 0.00073
# Epoch 80/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.3539e-04 - val_loss: 7.5503e-04
#
# Epoch 00080: val_loss did not improve from 0.00073
# Epoch 81/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.2980e-04 - val_loss: 7.8997e-04
#
# Epoch 00081: val_loss did not improve from 0.00073
# Epoch 82/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 1.3306e-04 - val_loss: 7.5488e-04
#
# Epoch 00082: val_loss did not improve from 0.00073
# Epoch 83/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.3145e-04 - val_loss: 7.4246e-04
#
# Epoch 00083: val_loss did not improve from 0.00073
# Epoch 84/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.2869e-04 - val_loss: 7.4224e-04
#
# Epoch 00084: val_loss did not improve from 0.00073
# Epoch 85/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.3129e-04 - val_loss: 7.2025e-04
#
# Epoch 00085: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 86/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.2865e-04 - val_loss: 7.8301e-04
#
# Epoch 00086: val_loss did not improve from 0.00072
# Epoch 87/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.2460e-04 - val_loss: 7.5324e-04
#
# Epoch 00087: val_loss did not improve from 0.00072
# Epoch 88/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.2241e-04 - val_loss: 7.5000e-04
#
# Epoch 00088: val_loss did not improve from 0.00072
# Epoch 89/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.2253e-04 - val_loss: 7.4991e-04
#
# Epoch 00089: val_loss did not improve from 0.00072
# Epoch 90/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.1969e-04 - val_loss: 7.2148e-04
#
# Epoch 00090: val_loss did not improve from 0.00072
# Epoch 91/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.2047e-04 - val_loss: 7.6810e-04
#
# Epoch 00091: val_loss did not improve from 0.00072
# Epoch 92/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.1394e-04 - val_loss: 7.4926e-04
#
# Epoch 00092: val_loss did not improve from 0.00072
# Epoch 93/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.2014e-04 - val_loss: 7.7537e-04
#
# Epoch 00093: val_loss did not improve from 0.00072
# Epoch 94/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 1.1998e-04 - val_loss: 7.3858e-04
#
# Epoch 00094: val_loss did not improve from 0.00072
# Epoch 95/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 1.1799e-04 - val_loss: 7.8583e-04
#
# Epoch 00095: val_loss did not improve from 0.00072
# Epoch 96/150
# 1712/1712 [==============================] - 0s 202us/step - loss: 1.2108e-04 - val_loss: 8.6508e-04
#
# Epoch 00096: val_loss did not improve from 0.00072
# Epoch 97/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 1.2118e-04 - val_loss: 7.2595e-04
#
# Epoch 00097: val_loss did not improve from 0.00072
# Epoch 98/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 1.1631e-04 - val_loss: 7.4881e-04
#
# Epoch 00098: val_loss did not improve from 0.00072
# Epoch 99/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.1285e-04 - val_loss: 7.6045e-04
#
# Epoch 00099: val_loss did not improve from 0.00072
# Epoch 100/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.1569e-04 - val_loss: 7.6874e-04
#
# Epoch 00100: val_loss did not improve from 0.00072
# Epoch 101/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.1414e-04 - val_loss: 7.8055e-04
#
# Epoch 00101: val_loss did not improve from 0.00072
# Epoch 102/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 1.1202e-04 - val_loss: 7.5299e-04
#
# Epoch 00102: val_loss did not improve from 0.00072
# Epoch 103/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.0473e-04 - val_loss: 7.3130e-04
#
# Epoch 00103: val_loss did not improve from 0.00072
# Epoch 104/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 1.0715e-04 - val_loss: 7.7090e-04
#
# Epoch 00104: val_loss did not improve from 0.00072
# Epoch 105/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.0462e-04 - val_loss: 7.7973e-04
#
# Epoch 00105: val_loss did not improve from 0.00072
# Epoch 106/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 1.0746e-04 - val_loss: 7.9968e-04
#
# Epoch 00106: val_loss did not improve from 0.00072
# Epoch 107/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.0712e-04 - val_loss: 7.5493e-04
#
# Epoch 00107: val_loss did not improve from 0.00072
# Epoch 108/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.0437e-04 - val_loss: 7.8158e-04
#
# Epoch 00108: val_loss did not improve from 0.00072
# Epoch 109/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.0622e-04 - val_loss: 7.7903e-04
#
# Epoch 00109: val_loss did not improve from 0.00072
# Epoch 110/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 1.0570e-04 - val_loss: 7.4267e-04
#
# Epoch 00110: val_loss did not improve from 0.00072
# Epoch 111/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.0288e-04 - val_loss: 7.3395e-04
#
# Epoch 00111: val_loss did not improve from 0.00072
# Epoch 112/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 9.9791e-05 - val_loss: 7.8234e-04
#
# Epoch 00112: val_loss did not improve from 0.00072
# Epoch 113/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.0162e-04 - val_loss: 7.6437e-04
#
# Epoch 00113: val_loss did not improve from 0.00072
# Epoch 114/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 1.0273e-04 - val_loss: 7.7343e-04
#
# Epoch 00114: val_loss did not improve from 0.00072
# Epoch 115/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.0029e-04 - val_loss: 7.7219e-04
#
# Epoch 00115: val_loss did not improve from 0.00072
# Epoch 116/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.0009e-04 - val_loss: 7.2123e-04
#
# Epoch 00116: val_loss did not improve from 0.00072
# Epoch 117/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.0213e-04 - val_loss: 7.5900e-04
#
# Epoch 00117: val_loss did not improve from 0.00072
# Epoch 118/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 9.9407e-05 - val_loss: 7.5002e-04
#
# Epoch 00118: val_loss did not improve from 0.00072
# Epoch 119/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 9.6893e-05 - val_loss: 7.6275e-04
#
# Epoch 00119: val_loss did not improve from 0.00072
# Epoch 120/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.0439e-04 - val_loss: 7.9687e-04
#
# Epoch 00120: val_loss did not improve from 0.00072
# Epoch 121/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 9.7563e-05 - val_loss: 7.7816e-04
#
# Epoch 00121: val_loss did not improve from 0.00072
# Epoch 122/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 9.5209e-05 - val_loss: 7.5380e-04
#
# Epoch 00122: val_loss did not improve from 0.00072
# Epoch 123/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 9.3723e-05 - val_loss: 7.6550e-04
#
# Epoch 00123: val_loss did not improve from 0.00072
# Epoch 124/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 9.5313e-05 - val_loss: 7.7733e-04
#
# Epoch 00124: val_loss did not improve from 0.00072
# Epoch 125/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 9.2603e-05 - val_loss: 7.7137e-04
#
# Epoch 00125: val_loss did not improve from 0.00072
# Epoch 126/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 9.2072e-05 - val_loss: 7.4918e-04
#
# Epoch 00126: val_loss did not improve from 0.00072
# Epoch 127/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 9.7148e-05 - val_loss: 7.5907e-04
#
# Epoch 00127: val_loss did not improve from 0.00072
# Epoch 128/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 9.4221e-05 - val_loss: 7.7012e-04
#
# Epoch 00128: val_loss did not improve from 0.00072
# Epoch 129/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 9.2783e-05 - val_loss: 7.5972e-04
#
# Epoch 00129: val_loss did not improve from 0.00072
# Epoch 130/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 9.1180e-05 - val_loss: 7.7571e-04
#
# Epoch 00130: val_loss did not improve from 0.00072
# Epoch 131/150
# 1712/1712 [==============================] - 0s 207us/step - loss: 9.2431e-05 - val_loss: 7.5785e-04
#
# Epoch 00131: val_loss did not improve from 0.00072
# Epoch 132/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 9.3201e-05 - val_loss: 7.4665e-04
#
# Epoch 00132: val_loss did not improve from 0.00072
# Epoch 133/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 9.2473e-05 - val_loss: 7.4397e-04
#
# Epoch 00133: val_loss did not improve from 0.00072
# Epoch 134/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 9.2097e-05 - val_loss: 7.6594e-04
#
# Epoch 00134: val_loss did not improve from 0.00072
# Epoch 135/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 8.9925e-05 - val_loss: 7.6417e-04
#
# Epoch 00135: val_loss did not improve from 0.00072
# Epoch 136/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 8.7064e-05 - val_loss: 7.8341e-04
#
# Epoch 00136: val_loss did not improve from 0.00072
# Epoch 137/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 8.8703e-05 - val_loss: 7.2845e-04
#
# Epoch 00137: val_loss did not improve from 0.00072
# Epoch 138/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 9.0257e-05 - val_loss: 7.7613e-04
#
# Epoch 00138: val_loss did not improve from 0.00072
# Epoch 139/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 8.7697e-05 - val_loss: 7.5512e-04
#
# Epoch 00139: val_loss did not improve from 0.00072
# Epoch 140/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 8.5212e-05 - val_loss: 7.7551e-04
#
# Epoch 00140: val_loss did not improve from 0.00072
# Epoch 141/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 8.6859e-05 - val_loss: 7.6919e-04
#
# Epoch 00141: val_loss did not improve from 0.00072
# Epoch 142/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 8.5759e-05 - val_loss: 7.6916e-04
#
# Epoch 00142: val_loss did not improve from 0.00072
# Epoch 143/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 8.6013e-05 - val_loss: 7.8262e-04
#
# Epoch 00143: val_loss did not improve from 0.00072
# Epoch 144/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 8.3234e-05 - val_loss: 7.6871e-04
#
# Epoch 00144: val_loss did not improve from 0.00072
# Epoch 145/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 8.4235e-05 - val_loss: 7.6973e-04
#
# Epoch 00145: val_loss did not improve from 0.00072
# Epoch 146/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 8.1996e-05 - val_loss: 7.7229e-04
#
# Epoch 00146: val_loss did not improve from 0.00072
# Epoch 147/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 8.2964e-05 - val_loss: 7.7686e-04
#
# Epoch 00147: val_loss did not improve from 0.00072
# Epoch 148/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 8.2361e-05 - val_loss: 7.5288e-04
#
# Epoch 00148: val_loss did not improve from 0.00072
# Epoch 149/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 8.4197e-05 - val_loss: 7.4212e-04
#
# Epoch 00149: val_loss did not improve from 0.00072
# Epoch 150/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 8.1038e-05 - val_loss: 7.6642e-04
#
# Epoch 00150: val_loss did not improve from 0.00072

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    #np.squeeze 从数组的形状中删除单维度条目，即把shape中为1的维度去掉
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
# 實現圖片以及關鍵點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# List convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 1s 339us/step - loss: 0.0052 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00204, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00204 to 0.00189, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00189 to 0.00179, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 9.1426e-04 - val_loss: 0.0015
#
# Epoch 00004: val_loss improved from 0.00179 to 0.00154, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 7.2472e-04 - val_loss: 0.0013
#
# Epoch 00005: val_loss improved from 0.00154 to 0.00129, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 5.8951e-04 - val_loss: 0.0011
#
# Epoch 00006: val_loss improved from 0.00129 to 0.00107, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 5.1134e-04 - val_loss: 9.8085e-04
#
# Epoch 00007: val_loss improved from 0.00107 to 0.00098, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 4.6596e-04 - val_loss: 9.2050e-04
#
# Epoch 00008: val_loss improved from 0.00098 to 0.00092, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 4.3113e-04 - val_loss: 8.8252e-04
#
# Epoch 00009: val_loss improved from 0.00092 to 0.00088, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 4.0176e-04 - val_loss: 8.5614e-04
#
# Epoch 00010: val_loss improved from 0.00088 to 0.00086, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 3.8233e-04 - val_loss: 8.7803e-04
#
# Epoch 00011: val_loss did not improve from 0.00086
# Epoch 12/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 3.5490e-04 - val_loss: 7.8826e-04
#
# Epoch 00012: val_loss improved from 0.00086 to 0.00079, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 3.3458e-04 - val_loss: 8.2343e-04
#
# Epoch 00013: val_loss did not improve from 0.00079
# Epoch 14/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 3.2211e-04 - val_loss: 7.6133e-04
#
# Epoch 00014: val_loss improved from 0.00079 to 0.00076, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 3.0620e-04 - val_loss: 7.4202e-04
#
# Epoch 00015: val_loss improved from 0.00076 to 0.00074, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 1s 285us/step - loss: 3.0095e-04 - val_loss: 7.1783e-04
#
# Epoch 00016: val_loss improved from 0.00074 to 0.00072, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 2.9581e-04 - val_loss: 7.2815e-04
#
# Epoch 00017: val_loss did not improve from 0.00072
# Epoch 18/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 2.8247e-04 - val_loss: 7.0669e-04
#
# Epoch 00018: val_loss improved from 0.00072 to 0.00071, saving model to best_weights_augment.h5
# Epoch 19/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 2.6789e-04 - val_loss: 7.1750e-04
#
# Epoch 00019: val_loss did not improve from 0.00071
# Epoch 20/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 2.6303e-04 - val_loss: 7.3018e-04
#
# Epoch 00020: val_loss did not improve from 0.00071
# Epoch 21/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 2.5387e-04 - val_loss: 7.0810e-04
#
# Epoch 00021: val_loss did not improve from 0.00071
# Epoch 22/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 2.4748e-04 - val_loss: 6.9200e-04
#
# Epoch 00022: val_loss improved from 0.00071 to 0.00069, saving model to best_weights_augment.h5
# Epoch 23/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 2.3564e-04 - val_loss: 6.7314e-04
#
# Epoch 00023: val_loss improved from 0.00069 to 0.00067, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 2.3595e-04 - val_loss: 7.0108e-04
#
# Epoch 00024: val_loss did not improve from 0.00067
# Epoch 25/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 2.2804e-04 - val_loss: 6.7520e-04
#
# Epoch 00025: val_loss did not improve from 0.00067
# Epoch 26/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 2.2490e-04 - val_loss: 7.1039e-04
#
# Epoch 00026: val_loss did not improve from 0.00067
# Epoch 27/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 2.1743e-04 - val_loss: 6.8184e-04
#
# Epoch 00027: val_loss did not improve from 0.00067
# Epoch 28/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 2.1393e-04 - val_loss: 6.8320e-04
#
# Epoch 00028: val_loss did not improve from 0.00067
# Epoch 29/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 2.0972e-04 - val_loss: 7.3833e-04
#
# Epoch 00029: val_loss did not improve from 0.00067
# Epoch 30/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 2.1029e-04 - val_loss: 6.6874e-04
#
# Epoch 00030: val_loss improved from 0.00067 to 0.00067, saving model to best_weights_augment.h5
# Epoch 31/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 2.0622e-04 - val_loss: 6.9599e-04
#
# Epoch 00031: val_loss did not improve from 0.00067
# Epoch 32/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.9673e-04 - val_loss: 6.5250e-04
#
# Epoch 00032: val_loss improved from 0.00067 to 0.00065, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.9312e-04 - val_loss: 6.9529e-04
#
# Epoch 00033: val_loss did not improve from 0.00065
# Epoch 34/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.9080e-04 - val_loss: 6.2668e-04
#
# Epoch 00034: val_loss improved from 0.00065 to 0.00063, saving model to best_weights_augment.h5
# Epoch 35/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 1.8863e-04 - val_loss: 6.3618e-04
#
# Epoch 00035: val_loss did not improve from 0.00063
# Epoch 36/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.8170e-04 - val_loss: 6.4006e-04
#
# Epoch 00036: val_loss did not improve from 0.00063
# Epoch 37/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 1.7890e-04 - val_loss: 6.3830e-04
#
# Epoch 00037: val_loss did not improve from 0.00063
# Epoch 38/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 1.7505e-04 - val_loss: 6.7102e-04
#
# Epoch 00038: val_loss did not improve from 0.00063
# Epoch 39/150
# 3424/3424 [==============================] - 1s 216us/step - loss: 1.7348e-04 - val_loss: 6.1654e-04
#
# Epoch 00039: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 40/150
# 3424/3424 [==============================] - 1s 216us/step - loss: 1.7398e-04 - val_loss: 6.4646e-04
#
# Epoch 00040: val_loss did not improve from 0.00062
# Epoch 41/150
# 3424/3424 [==============================] - 1s 227us/step - loss: 1.6961e-04 - val_loss: 6.4496e-04
#
# Epoch 00041: val_loss did not improve from 0.00062
# Epoch 42/150
# 3424/3424 [==============================] - 1s 224us/step - loss: 1.6939e-04 - val_loss: 6.3779e-04
#
# Epoch 00042: val_loss did not improve from 0.00062
# Epoch 43/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 1.6534e-04 - val_loss: 6.6372e-04
#
# Epoch 00043: val_loss did not improve from 0.00062
# Epoch 44/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 1.6335e-04 - val_loss: 6.3681e-04
# Epoch 00044: val_loss did not improve from 0.00062
# Epoch 45/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 1.5736e-04 - val_loss: 6.6050e-04
#
# Epoch 00045: val_loss did not improve from 0.00062
# Epoch 46/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.5585e-04 - val_loss: 6.7006e-04
#
# Epoch 00046: val_loss did not improve from 0.00062
# Epoch 47/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 1.6111e-04 - val_loss: 6.2662e-04
#
# Epoch 00047: val_loss did not improve from 0.00062
# Epoch 48/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 1.5627e-04 - val_loss: 6.4003e-04
#
# Epoch 00048: val_loss did not improve from 0.00062
# Epoch 49/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.5204e-04 - val_loss: 6.5207e-04
#
# Epoch 00049: val_loss did not improve from 0.00062
# Epoch 50/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 1.4737e-04 - val_loss: 6.4027e-04
#
# Epoch 00050: val_loss did not improve from 0.00062
# Epoch 51/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 1.4931e-04 - val_loss: 6.2286e-04
#
# Epoch 00051: val_loss did not improve from 0.00062
# Epoch 52/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 1.4729e-04 - val_loss: 6.4452e-04
#
# Epoch 00052: val_loss did not improve from 0.00062
# Epoch 53/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 1.4741e-04 - val_loss: 6.2894e-04
#
# Epoch 00053: val_loss did not improve from 0.00062
# Epoch 54/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.4197e-04 - val_loss: 6.4908e-04
#
# Epoch 00054: val_loss did not improve from 0.00062
# Epoch 55/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.3978e-04 - val_loss: 6.1108e-04
#
# Epoch 00055: val_loss improved from 0.00062 to 0.00061, saving model to best_weights_augment.h5
# Epoch 56/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.4138e-04 - val_loss: 6.5328e-04
#
# Epoch 00056: val_loss did not improve from 0.00061
# Epoch 57/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 1.3830e-04 - val_loss: 6.5534e-04
#
# Epoch 00057: val_loss did not improve from 0.00061
# Epoch 58/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 1.3687e-04 - val_loss: 6.5755e-04
#
# Epoch 00058: val_loss did not improve from 0.00061
# Epoch 59/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 1.3362e-04 - val_loss: 6.2714e-04
#
# Epoch 00059: val_loss did not improve from 0.00061
# Epoch 60/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 1.3782e-04 - val_loss: 6.1848e-04
#
# Epoch 00060: val_loss did not improve from 0.00061
# Epoch 61/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 1.3180e-04 - val_loss: 6.1482e-04
#
# Epoch 00061: val_loss did not improve from 0.00061
# Epoch 62/150
# 3424/3424 [==============================] - 1s 216us/step - loss: 1.2900e-04 - val_loss: 6.4564e-04
#
# Epoch 00062: val_loss did not improve from 0.00061
# Epoch 63/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.2770e-04 - val_loss: 6.3181e-04
#
# Epoch 00063: val_loss did not improve from 0.00061
# Epoch 64/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.2663e-04 - val_loss: 6.2155e-04
#
# Epoch 00064: val_loss did not improve from 0.00061
# Epoch 65/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.2434e-04 - val_loss: 6.3659e-04
#
# Epoch 00065: val_loss did not improve from 0.00061
# Epoch 66/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.2562e-04 - val_loss: 6.3363e-04
#
# Epoch 00066: val_loss did not improve from 0.00061
# Epoch 67/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 1.2416e-04 - val_loss: 6.2145e-04
#
# Epoch 00067: val_loss did not improve from 0.00061
# Epoch 68/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 1.2419e-04 - val_loss: 6.2763e-04
#
# Epoch 00068: val_loss did not improve from 0.00061
# Epoch 69/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.2221e-04 - val_loss: 6.7979e-04
#
# Epoch 00069: val_loss did not improve from 0.00061
# Epoch 70/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 1.2356e-04 - val_loss: 6.4707e-04
#
# Epoch 00070: val_loss did not improve from 0.00061
# Epoch 71/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.2166e-04 - val_loss: 6.6080e-04
#
# Epoch 00071: val_loss did not improve from 0.00061
# Epoch 72/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 1.1812e-04 - val_loss: 6.2197e-04
#
# Epoch 00072: val_loss did not improve from 0.00061
# Epoch 73/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.1707e-04 - val_loss: 6.3420e-04
#
# Epoch 00073: val_loss did not improve from 0.00061
# Epoch 74/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 1.1512e-04 - val_loss: 6.1682e-04
#
# Epoch 00074: val_loss did not improve from 0.00061
# Epoch 75/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 1.1491e-04 - val_loss: 6.2326e-04
#
# Epoch 00075: val_loss did not improve from 0.00061
# Epoch 76/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 1.1384e-04 - val_loss: 6.4800e-04
#
# Epoch 00076: val_loss did not improve from 0.00061
# Epoch 77/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 1.1163e-04 - val_loss: 6.3235e-04
#
# Epoch 00077: val_loss did not improve from 0.00061
# Epoch 78/150
# 3424/3424 [==============================] - 1s 226us/step - loss: 1.1475e-04 - val_loss: 6.2308e-04
#
# Epoch 00078: val_loss did not improve from 0.00061
# Epoch 79/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 1.1253e-04 - val_loss: 6.4333e-04
#
# Epoch 00079: val_loss did not improve from 0.00061
# Epoch 80/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 1.1069e-04 - val_loss: 6.4641e-04
#
# Epoch 00080: val_loss did not improve from 0.00061
# Epoch 81/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 1.0961e-04 - val_loss: 6.3004e-04
#
# Epoch 00081: val_loss did not improve from 0.00061
# Epoch 82/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 1.0850e-04 - val_loss: 6.2244e-04
#
# Epoch 00082: val_loss did not improve from 0.00061
# Epoch 83/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 1.0570e-04 - val_loss: 6.3235e-04
#
# Epoch 00083: val_loss did not improve from 0.00061
# Epoch 84/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.0836e-04 - val_loss: 6.4545e-04
#
# Epoch 00084: val_loss did not improve from 0.00061
# Epoch 85/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 1.0574e-04 - val_loss: 6.3851e-04
#
# Epoch 00085: val_loss did not improve from 0.00061
# Epoch 86/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 1.0374e-04 - val_loss: 6.2394e-04
#
# Epoch 00086: val_loss did not improve from 0.00061
# Epoch 87/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 1.0648e-04 - val_loss: 6.3023e-04
#
# Epoch 00087: val_loss did not improve from 0.00061
# Epoch 88/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 1.0562e-04 - val_loss: 6.7321e-04
#
# Epoch 00088: val_loss did not improve from 0.00061
# Epoch 89/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 1.0500e-04 - val_loss: 6.2151e-04
#
# Epoch 00089: val_loss did not improve from 0.00061
# Epoch 90/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 1.0330e-04 - val_loss: 6.3162e-04
#
# Epoch 00090: val_loss did not improve from 0.00061
# Epoch 91/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 1.0285e-04 - val_loss: 6.3274e-04
#
# Epoch 00091: val_loss did not improve from 0.00061
# Epoch 92/150
# 3424/3424 [==============================] - 1s 224us/step - loss: 1.0261e-04 - val_loss: 6.4414e-04
#
# Epoch 00092: val_loss did not improve from 0.00061
# Epoch 93/150
# 3424/3424 [==============================] - 1s 227us/step - loss: 1.0073e-04 - val_loss: 6.3458e-04
#
# Epoch 00093: val_loss did not improve from 0.00061
# Epoch 94/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 9.9911e-05 - val_loss: 6.2406e-04
#
# Epoch 00094: val_loss did not improve from 0.00061
# Epoch 95/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 1.0022e-04 - val_loss: 6.4747e-04
#
# Epoch 00095: val_loss did not improve from 0.00061
# Epoch 96/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 9.9408e-05 - val_loss: 6.4810e-04
#
# Epoch 00096: val_loss did not improve from 0.00061
# Epoch 97/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 9.9486e-05 - val_loss: 6.2140e-04
#
# Epoch 00097: val_loss did not improve from 0.00061
# Epoch 98/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 9.8524e-05 - val_loss: 6.3620e-04
#
# Epoch 00098: val_loss did not improve from 0.00061
# Epoch 99/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 9.6557e-05 - val_loss: 6.3460e-04
#
# Epoch 00099: val_loss did not improve from 0.00061
# Epoch 100/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 9.8099e-05 - val_loss: 6.2333e-04
#
# Epoch 00100: val_loss did not improve from 0.00061
# Epoch 101/150
# 3424/3424 [==============================] - 1s 225us/step - loss: 9.7563e-05 - val_loss: 6.1532e-04
#
# Epoch 00101: val_loss did not improve from 0.00061
# Epoch 102/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 9.6127e-05 - val_loss: 6.4531e-04
#
# Epoch 00102: val_loss did not improve from 0.00061
# Epoch 103/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 9.4680e-05 - val_loss: 6.2548e-04
#
# Epoch 00103: val_loss did not improve from 0.00061
# Epoch 104/150
# 3424/3424 [==============================] - 1s 217us/step - loss: 9.2506e-05 - val_loss: 6.2190e-04
#
# Epoch 00104: val_loss did not improve from 0.00061
# Epoch 105/150
# 3424/3424 [==============================] - 1s 214us/step - loss: 9.2597e-05 - val_loss: 6.4200e-04
#
# Epoch 00105: val_loss did not improve from 0.00061
# Epoch 106/150
# 3424/3424 [==============================] - 1s 215us/step - loss: 9.3593e-05 - val_loss: 6.4387e-04
#
# Epoch 00106: val_loss did not improve from 0.00061
# Epoch 107/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 9.2542e-05 - val_loss: 6.4407e-04
#
# Epoch 00107: val_loss did not improve from 0.00061
# Epoch 108/150
# 3424/3424 [==============================] - 1s 231us/step - loss: 9.3487e-05 - val_loss: 6.3059e-04
#
# Epoch 00108: val_loss did not improve from 0.00061
# Epoch 109/150
# 3424/3424 [==============================] - 1s 228us/step - loss: 9.4010e-05 - val_loss: 6.4826e-04
#
# Epoch 00109: val_loss did not improve from 0.00061
# Epoch 110/150
# 3424/3424 [==============================] - 1s 228us/step - loss: 9.4316e-05 - val_loss: 6.2254e-04
#
# Epoch 00110: val_loss did not improve from 0.00061
# Epoch 111/150
# 3424/3424 [==============================] - 1s 228us/step - loss: 9.7571e-05 - val_loss: 6.2898e-04
#
# Epoch 00111: val_loss did not improve from 0.00061
# Epoch 112/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 9.5134e-05 - val_loss: 6.3576e-04
#
# Epoch 00112: val_loss did not improve from 0.00061
# Epoch 113/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 9.3237e-05 - val_loss: 6.3127e-04
#
# Epoch 00113: val_loss did not improve from 0.00061
# Epoch 114/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 9.2368e-05 - val_loss: 6.2416e-04
#
# Epoch 00114: val_loss did not improve from 0.00061
# Epoch 115/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 9.1536e-05 - val_loss: 6.6130e-04
#
# Epoch 00115: val_loss did not improve from 0.00061
# Epoch 116/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 9.1096e-05 - val_loss: 6.3237e-04
#
# Epoch 00116: val_loss did not improve from 0.00061
# Epoch 117/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 9.1407e-05 - val_loss: 6.3683e-04
#
# Epoch 00117: val_loss did not improve from 0.00061
# Epoch 118/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 9.2160e-05 - val_loss: 6.3540e-04
#
# Epoch 00118: val_loss did not improve from 0.00061
# Epoch 119/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 9.1494e-05 - val_loss: 6.1515e-04
#
# Epoch 00119: val_loss did not improve from 0.00061
# Epoch 120/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 9.1783e-05 - val_loss: 6.3618e-04
#
# Epoch 00120: val_loss did not improve from 0.00061
# Epoch 121/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 8.8558e-05 - val_loss: 6.9286e-04
#
# Epoch 00121: val_loss did not improve from 0.00061
# Epoch 122/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 8.7155e-05 - val_loss: 6.4066e-04
#
# Epoch 00122: val_loss did not improve from 0.00061
# Epoch 123/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 8.8999e-05 - val_loss: 6.3901e-04
#
# Epoch 00123: val_loss did not improve from 0.00061
# Epoch 124/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 8.7232e-05 - val_loss: 6.3374e-04
#
# Epoch 00124: val_loss did not improve from 0.00061
# Epoch 125/150
# 3424/3424 [==============================] - 1s 224us/step - loss: 8.6482e-05 - val_loss: 6.3175e-04
#
# Epoch 00125: val_loss did not improve from 0.00061
# Epoch 126/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 8.7033e-05 - val_loss: 6.2100e-04
#
# Epoch 00126: val_loss did not improve from 0.00061
# Epoch 127/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 8.5880e-05 - val_loss: 6.3400e-04
#
# Epoch 00127: val_loss did not improve from 0.00061
# Epoch 128/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 8.5958e-05 - val_loss: 6.1888e-04
#
# Epoch 00128: val_loss did not improve from 0.00061
# Epoch 129/150
# 3424/3424 [==============================] - 1s 230us/step - loss: 8.4747e-05 - val_loss: 6.4367e-04
#
# Epoch 00129: val_loss did not improve from 0.00061
# Epoch 130/150
# 3424/3424 [==============================] - 1s 227us/step - loss: 8.4912e-05 - val_loss: 6.3788e-04
#
# Epoch 00130: val_loss did not improve from 0.00061
# Epoch 131/150
# 3424/3424 [==============================] - 1s 225us/step - loss: 8.5591e-05 - val_loss: 6.3984e-04
#
# Epoch 00131: val_loss did not improve from 0.00061
# Epoch 132/150
# 3424/3424 [==============================] - 1s 225us/step - loss: 8.6213e-05 - val_loss: 6.2486e-04
#
# Epoch 00132: val_loss did not improve from 0.00061
# Epoch 133/150
# 3424/3424 [==============================] - 1s 227us/step - loss: 8.6032e-05 - val_loss: 6.6166e-04
#
# Epoch 00133: val_loss did not improve from 0.00061
# Epoch 134/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 8.6369e-05 - val_loss: 6.3746e-04
#
# Epoch 00134: val_loss did not improve from 0.00061
# Epoch 135/150
# 3424/3424 [==============================] - 1s 219us/step - loss: 8.5624e-05 - val_loss: 6.4197e-04
#
# Epoch 00135: val_loss did not improve from 0.00061
# Epoch 136/150
# 3424/3424 [==============================] - 1s 224us/step - loss: 8.5264e-05 - val_loss: 6.3730e-04
#
# Epoch 00136: val_loss did not improve from 0.00061
# Epoch 137/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 8.3741e-05 - val_loss: 6.4753e-04
#
# Epoch 00137: val_loss did not improve from 0.00061
# Epoch 138/150
# 3424/3424 [==============================] - 1s 218us/step - loss: 8.4790e-05 - val_loss: 6.3740e-04
#
# Epoch 00138: val_loss did not improve from 0.00061
# Epoch 139/150
# 3424/3424 [==============================] - 1s 228us/step - loss: 8.3096e-05 - val_loss: 6.3745e-04
#
# Epoch 00139: val_loss did not improve from 0.00061
# Epoch 140/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 8.4408e-05 - val_loss: 6.3436e-04
#
# Epoch 00140: val_loss did not improve from 0.00061
# Epoch 141/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 8.2738e-05 - val_loss: 6.4482e-04
#
# Epoch 00141: val_loss did not improve from 0.00061
# Epoch 142/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 8.4783e-05 - val_loss: 6.5917e-04
#
# Epoch 00142: val_loss did not improve from 0.00061
# Epoch 143/150
# 3424/3424 [==============================] - 1s 225us/step - loss: 8.3598e-05 - val_loss: 6.6288e-04
#
# Epoch 00143: val_loss did not improve from 0.00061
# Epoch 144/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 8.5617e-05 - val_loss: 6.6127e-04
#
# Epoch 00144: val_loss did not improve from 0.00061
# Epoch 145/150
# 3424/3424 [==============================] - 1s 222us/step - loss: 8.2035e-05 - val_loss: 6.3626e-04
#
# Epoch 00145: val_loss did not improve from 0.00061
# Epoch 146/150
# 3424/3424 [==============================] - 1s 221us/step - loss: 8.3338e-05 - val_loss: 6.2855e-04
#
# Epoch 00146: val_loss did not improve from 0.00061
# Epoch 147/150
# 3424/3424 [==============================] - 1s 220us/step - loss: 8.3095e-05 - val_loss: 6.5511e-04
#
# Epoch 00147: val_loss did not improve from 0.00061
# Epoch 148/150
# 3424/3424 [==============================] - 1s 223us/step - loss: 8.0148e-05 - val_loss: 6.4525e-04
#
# Epoch 00148: val_loss did not improve from 0.00061
# Epoch 149/150
# 3424/3424 [==============================] - 1s 228us/step - loss: 8.1705e-05 - val_loss: 6.2780e-04
#
# Epoch 00149: val_loss did not improve from 0.00061
# Epoch 150/150
# 3424/3424 [==============================] - 1s 243us/step - loss: 8.0030e-05 - val_loss: 6.4398e-04
#
# Epoch 00150: val_loss did not improve from 0.00061

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
